# 67  2015      8        NaN   NaN        NaN        NaN          NaN       NaN
# 68  2015      9        NaN   NaN        NaN        NaN          NaN       NaN
# 69  2015     10        NaN   NaN        NaN        NaN          NaN       NaN
# 70  2015     11        NaN   NaN        NaN        NaN          NaN       NaN
# 71  2015     12        NaN   NaN        NaN        NaN          NaN       NaN
# 72  2016      1        NaN   NaN        NaN        NaN          NaN       NaN
# 73  2016      2        NaN   NaN        NaN        NaN          NaN       NaN
# 74  2016      3        NaN   NaN        NaN        NaN          NaN       NaN
# 75  2016      4        NaN   NaN        NaN        NaN          NaN       NaN
# 76  2016      5        NaN   NaN        NaN        NaN          NaN       NaN
# 77  2016      6        NaN   NaN        NaN        NaN          NaN       NaN
# 78  2016      7        NaN   NaN        NaN        NaN          NaN       NaN
# 79  2016      8        NaN   NaN        NaN        NaN          NaN       NaN
# 80  2016      9        NaN   NaN        NaN        NaN          NaN       NaN
# 81  2016     10        NaN   NaN        NaN        NaN          NaN       NaN
# 82  2016     11        NaN   NaN        NaN        NaN          NaN       NaN
# 83  2016     12        NaN   NaN        NaN        NaN          NaN       NaN
# 84  2017      1        NaN   NaN        NaN        NaN          NaN       NaN
# 85  2017      2        NaN   NaN        NaN        NaN          NaN       NaN
# 86  2017      3        NaN   NaN        NaN        NaN          NaN       NaN
# 87  2017      4        NaN   NaN        NaN        NaN          NaN       NaN
# 88  2017      5        NaN   NaN        NaN        NaN          NaN       NaN
# 89  2017      6        NaN   NaN        NaN        NaN          NaN       NaN
# 90  2017      7        NaN   NaN        NaN        NaN          NaN       NaN
#
#      TOTALOIL Label
# 0   48131.725   PFZ
# 1   20158.942   PFZ
# 2   33400.703  NPFZ
# 3    7268.411  NPFZ
# 4   16186.259  NPFZ
# 5   15007.071  NPFZ
# 6   15495.134  NPFZ
# 7    6259.526  NPFZ
# 8   29318.867   PFZ
# 9   37132.879   PFZ
# 10  52090.460   PFZ
# 11  71906.825   PFZ
# 12  57378.142   PFZ
# 13  32440.026   PFZ
# 14   5138.233  NPFZ
# 15  28827.870   PFZ
# 16  43934.098   PFZ
# 17  10643.353  NPFZ
# 18  20818.942   PFZ
# 19  30696.895  NPFZ
# 20  19586.576   PFZ
# 21  41957.683   PFZ
# 22  42033.875   PFZ
# 23  69835.406   PFZ
# 24  51699.530   PFZ
# 25  33361.893   PFZ
# 26  39862.426   PFZ
# 27  14151.874  NPFZ
# 28  43065.211   PFZ
# 29  16766.315  NPFZ
# ..        ...   ...
# 61        NaN   NaN
# 62        NaN   NaN
# 63        NaN   NaN
# 64        NaN   NaN
# 65        NaN   NaN
# 66        NaN   NaN
# 67        NaN   NaN
# 68        NaN   NaN
# 69        NaN   NaN
# 70        NaN   NaN
# 71        NaN   NaN
# 72        NaN   NaN
# 73        NaN   NaN
# 74        NaN   NaN
# 75        NaN   NaN
# 76        NaN   NaN
# 77        NaN   NaN
# 78        NaN   NaN
# 79        NaN   NaN
# 80        NaN   NaN
# 81        NaN   NaN
# 82        NaN   NaN
# 83        NaN   NaN
# 84        NaN   NaN
# 85        NaN   NaN
# 86        NaN   NaN
# 87        NaN   NaN
# 88        NaN   NaN
# 89        NaN   NaN
# 90        NaN   NaN
#
# [91 rows x 10 columns]

# %%
'''
Sea Surface Temperature, Chlorophyll, 
Relative Humidity, Sea Level Pressure, Air Temperature, Total Cloudiness and Total Fish catch data.

'''
# Out:
# '\nSea Surface Temperature, Chlorophyll, \nRelative Humidity, Sea Level Pressure, Air Temperature, Total Cloudiness and Total Fish catch data.\n\n'

# %% [markdown]
# # Remove year and Month and Label

# %%
df =  td[['SST', 'SSC', 'AT', 'RH', 'SLP', 'TC', 'TOTALOIL']]
df
# Out:
#           SST   SSC         AT         RH          SLP        TC   TOTALOIL
# 0   28.659535  0.24  27.927021  76.067391  1013.386250  3.438298  48131.725
# 1   28.506889  0.19  28.140408  74.979592  1012.342449  2.791837  20158.942
# 2   29.359070  0.18  28.922500  76.359574  1012.280417  3.511111  33400.703
# 3   30.385854  0.26  29.801250  78.610417  1009.744792  4.110638   7268.411
# 4   30.749362  0.24  30.292000  77.500000  1008.289600  4.424000  16186.259
# 5   29.269796  0.26  28.539796  81.128571  1007.825600  6.142857  15007.071
# 6   28.494490  0.12  27.649388  83.665306  1007.790400  6.606122  15495.134
# 7   27.470444  0.19  27.063043  83.360870  1009.054681  5.747826   6259.526
# 8   28.020000  0.17  27.724167  81.706250  1008.252000  5.122449  29318.867
# 9   29.010773  0.21  28.369584  79.348464  1010.446150  4.794784  37132.879
# 10  29.000980  0.19  27.973333  79.550980  1009.366078  4.888235  52090.460
# 11  28.392000  0.12  27.458889  74.524444  1009.368636  3.581395  71906.825
# 12  27.924444  0.18  27.252128  75.686957  1011.223556  2.917391  57378.142
# 13  27.935227  0.19  27.489792  72.123404  1011.401875  2.745833  32440.026
# 14  28.713878  0.16  28.506531  75.675510  1010.495918  2.683333   5138.233
# 15  29.667045  0.18  29.433696  75.321739  1009.730870  3.620455  28827.870
# 16  29.938571  0.16  29.772600  77.998000  1009.677600  3.948000  43934.098
# 17  29.036667  0.18  28.596875  81.393617  1007.970417  5.682979  10643.353
# 18  28.321778  0.20  27.515745  84.241304  1008.132979  6.520000  20818.942
# 19  28.015217  0.26  27.461064  84.313043  1007.970213  6.239130  30696.895
# 20  28.075000  0.18  27.489130  82.741304  1009.051702  5.560870  19586.576
# 21  29.265532  0.15  28.338000  79.153061  1010.341800  4.835417  41957.683
# 22  29.149070  0.16  28.321333  76.837778  1010.109333  4.497778  42033.875
# 23  28.474468  0.13  28.053191  74.239130  1010.849574  3.230435  69835.406
# 24  27.973902  0.11  26.987391  72.444186  1011.810870  3.214286  51699.530
# 25  28.181957  0.19  27.268776  77.008163  1010.893673  2.734043  33361.893
# 26  28.464884  0.18  27.879130  77.802222  1010.950217  3.153333  39862.426
# 27  29.356190  0.16  29.117391  77.686667  1009.645435  3.717778  14151.874
# 28  29.485909  0.22  28.889091  76.984091  1009.680227  3.711628  43065.211
# 29  28.886667  0.15  28.279412  81.819608  1008.375882  5.901961  16766.315
# ..        ...   ...        ...        ...          ...       ...        ...
# 61        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 62        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 63        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 64        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 65        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 66        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 67        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 68        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 69        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 70        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 71        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 72        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 73        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 74        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 75        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 76        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 77        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 78        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 79        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 80        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 81        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 82        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 83        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 84        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 85        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 86        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 87        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 88        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 89        NaN   NaN        NaN        NaN          NaN       NaN        NaN
# 90        NaN   NaN        NaN        NaN          NaN       NaN        NaN
#
# [91 rows x 7 columns]

# %% [markdown]
# # Shuffle the dataset and apply interpolate method

# %%
df = df.sample(frac=1).reset_index(drop=True)

# %%
nedf = df.interpolate(method='cubic', axis=0).ffill().bfill()

# %%
nedf = nedf.astype("float")
nedf
# Out:
#           SST       SSC         AT         RH          SLP        TC  \
# 0   29.356190  0.160000  29.117391  77.686667  1009.645435  3.717778
# 1   29.036667  0.180000  28.596875  81.393617  1007.970417  5.682979
# 2   28.392000  0.120000  27.458889  74.524444  1009.368636  3.581395
# 3   28.264561  0.153436  27.206719  72.660818  1011.681495  2.748212
# 4   28.373095  0.230000  27.545814  74.965854  1013.454318  3.148780
# 5   28.289171  0.264970  27.864007  77.327603  1013.736576  3.646026
# 6   28.119282  0.259706  28.076509  78.952411  1012.890410  4.063005
# 7   28.103651  0.237089  28.230377  79.876198  1011.606130  4.462804
# 82  28.015217  0.260000  27.461064  84.313043  1007.970213  6.239130
# 83  27.867658  0.233848  27.341577  80.364955  1008.860830  4.904737
# 84  27.924444  0.180000  27.252128  75.686957  1011.223556  2.917391
# 85  28.328903  0.165171  27.420609  72.234355  1013.349778  1.662911
# 86  28.832381  0.183171  27.711862  70.788094  1014.585875  1.374129
# 87  29.088229  0.209585  27.899966  71.835525  1014.541974  1.995630
# 88  28.749800  0.220000  27.759000  75.864000  1012.828200  3.472000
# 89  27.470444  0.190000  27.063043  83.360870  1009.054681  5.747826
# 90  27.470444  0.190000  27.063043  83.360870  1009.054681  5.747826
#
#         TOTALOIL
# 0   14151.874000
# 1   10643.353000
# 2   71906.825000
# 3   83904.077423
# 4   60903.643000
# 5   41241.974959
# 6   31220.463218
# 7   29131.731868
# 8   33268.405000
# 9   37132.879000
# 10  39862.426000
# 11  85752.874000
# 12  85669.631781
# 13  56088.725000
# 14  40999.276960
# 15  39597.822000
# 16  41485.263284
# 17  42672.568227
# 18  40773.220307
# 19  33400.703000
# 20  21530.560018
# 21  19586.576000
# 22  37782.926651
# 23  56047.111000
# 24  48131.725000
# 25  22412.000000
# 26  52090.460000
# 27  59662.800908
# 28  39331.485295
# 29  16403.606784
# ..           ...
# 61  26382.327043
# 62  20818.942000
# 63  21623.762309
# 64  32440.026000
# 65  43065.211000
# 66  18116.831243
# 67   7268.411000
# 68  42033.875000
# 69  28036.907956
# 70   5138.233000
# 71  25528.196000
# 72  34708.317195
# 73  29318.867000
# 74  23778.841861
# 75  20623.788642
# 76  19418.391813
# 77  19727.335846
# 78  21115.305211
# 79  23146.984378
# 80  25387.057817
# 81  27400.210000
# 82  30696.895000
# 83  41710.317680
# 84  57378.142000
# 85  71841.860020
# 86  79499.586720
# 87  74813.592810
# 88  52246.149000
# 89   6259.526000
# 90   6259.526000
#
# [91 rows x 7 columns]

# %% [markdown]
# # Create label

# %%
ssc = np.array(nedf['SSC'])
sst = np.array(nedf['SST'])
fc = np.array(nedf['TOTALOIL'])

# %%
lab = []
for i in range(len(ssc)):
    if ssc[i]>0.2 and sst[i]>25.0 and fc[i]>10000:
        lab.append("PFZ")
    else:
        lab.append("NPFZ")

# %%
label = pd.DataFrame(lab,columns=['label'])

# %%
dataset = pd.concat([nedf,label],axis=1)
dataset
# Out:
#           SST       SSC         AT         RH          SLP        TC  \
# 0   29.356190  0.160000  29.117391  77.686667  1009.645435  3.717778
# 1   29.036667  0.180000  28.596875  81.393617  1007.970417  5.682979
# 2   28.392000  0.120000  27.458889  74.524444  1009.368636  3.581395
# 3   28.264561  0.153436  27.206719  72.660818  1011.681495  2.748212
# 4   28.373095  0.230000  27.545814  74.965854  1013.454318  3.148780
# 5   28.289171  0.264970  27.864007  77.327603  1013.736576  3.646026
# 6   28.119282  0.259706  28.076509  78.952411  1012.890410  4.063005
# 7   28.103651  0.237089  28.230377  79.876198  1011.606130  4.462804
# 82  28.015217  0.260000  27.461064  84.313043  1007.970213  6.239130
# 83  27.867658  0.233848  27.341577  80.364955  1008.860830  4.904737
# 84  27.924444  0.180000  27.252128  75.686957  1011.223556  2.917391
# 85  28.328903  0.165171  27.420609  72.234355  1013.349778  1.662911
# 86  28.832381  0.183171  27.711862  70.788094  1014.585875  1.374129
# 87  29.088229  0.209585  27.899966  71.835525  1014.541974  1.995630
# 88  28.749800  0.220000  27.759000  75.864000  1012.828200  3.472000
# 89  27.470444  0.190000  27.063043  83.360870  1009.054681  5.747826
# 90  27.470444  0.190000  27.063043  83.360870  1009.054681  5.747826
#
#         TOTALOIL label
# 0   14151.874000  NPFZ
# 1   10643.353000  NPFZ
# 2   71906.825000  NPFZ
# 3   83904.077423  NPFZ
# 4   60903.643000   PFZ
# 5   41241.974959   PFZ
# 6   31220.463218   PFZ
# 7   29131.731868   PFZ
# 8   33268.405000   PFZ
# 9   37132.879000   PFZ
# 10  39862.426000  NPFZ
# 11  85752.874000   PFZ
# 12  85669.631781   PFZ
# 13  56088.725000   PFZ
# 14  40999.276960   PFZ
# 15  39597.822000   PFZ
# 16  41485.263284   PFZ
# 17  42672.568227   PFZ
# 18  40773.220307  NPFZ
# 19  33400.703000  NPFZ
# 20  21530.560018  NPFZ
# 21  19586.576000  NPFZ
# 22  37782.926651  NPFZ
# 23  56047.111000   PFZ
# 24  48131.725000   PFZ
# 25  22412.000000   PFZ
# 26  52090.460000  NPFZ
# 27  59662.800908   PFZ
# 28  39331.485295   PFZ
# 29  16403.606784   PFZ
# ..           ...   ...
# 61  26382.327043   PFZ
# 62  20818.942000  NPFZ
# 63  21623.762309  NPFZ
# 64  32440.026000  NPFZ
# 65  43065.211000   PFZ
# 66  18116.831243   PFZ
# 67   7268.411000  NPFZ
# 68  42033.875000  NPFZ
# 69  28036.907956  NPFZ
# 70   5138.233000  NPFZ
# 71  25528.196000  NPFZ
# 72  34708.317195  NPFZ
# 73  29318.867000  NPFZ
# 74  23778.841861  NPFZ
# 75  20623.788642  NPFZ
# 76  19418.391813  NPFZ
# 77  19727.335846  NPFZ
# 78  21115.305211  NPFZ
# 79  23146.984378  NPFZ
# 80  25387.057817  NPFZ
# 81  27400.210000   PFZ
# 82  30696.895000   PFZ
# 83  41710.317680   PFZ
# 84  57378.142000  NPFZ
# 85  71841.860020  NPFZ
# 86  79499.586720  NPFZ
# 87  74813.592810   PFZ
# 88  52246.149000   PFZ
# 89   6259.526000  NPFZ
# 90   6259.526000  NPFZ
#
# [91 rows x 8 columns]

# %%
dataset.to_csv("cubic_interpolation.csv",sep='\t', encoding='utf-8')

# %%
# create a copy
df1 = dataset

# %%
# mapping
df1['label']=df1['label'].map({'PFZ':0,'NPFZ':1})

# %% [markdown]
# # Drop Total catch

# %%
df2=df1.drop(['TOTALOIL'],axis=1)
df2.columns
# Out:
# Index(['SST', 'SSC', 'AT', 'RH', 'SLP', 'TC', 'label'], dtype='object')

# %% [markdown]
# # Split data and label

# %%
X = df2[['SST', 'SSC', 'AT', 'RH', 'SLP', 'TC']]
Y = df2[['label']]

# %% [markdown]
# # normalized the data and label

# %%
from sklearn import preprocessing

# %%
X_norm = preprocessing.normalize(X, norm='l2')

# %%
y = np.squeeze(np.array(Y).reshape(1,-1))

# %% [markdown]
# # Feature importance

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
model = ExtraTreesClassifier()
model.fit(X_norm,y)
feature_importance=model.feature_importances_
print(model.feature_importances_)
# Out:
# [ 0.14970827  0.49997222  0.09220078  0.07687765  0.09724603  0.08399504]

# %%
feature_importance = 100.0 * (feature_importance / feature_importance.max())
sorted_idx = np.argsort(feature_importance)
pos = np.arange(sorted_idx.shape[0]) + .8
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # apply machine learning

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_norm,y, test_size=0.33, random_state=40)

# %% [markdown]
# # SVM

# %%
from sklearn import svm

# %%
clf = svm.SVC() # svm classifer

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import precision_recall_curve

# %%
result1 = clf.predict(X_test)

# %%
confusion_matrix(y_test,result1)
# Out:
# array([[ 0,  9],
#        [ 0, 22]])

# %%
print(accuracy_score(result1,y_test))
# Out:
# 0.709677419355

# %% [markdown]
# # Boosted Tree

# %%
import xgboost as xgb

# %%
model_xgboost = xgb.XGBClassifier() # boosted tree classifire
model_xgboost.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
predXGB = model_xgboost.predict(X_test)
print(accuracy_score(predXGB,y_test))
# Out:
# 1.0

# %%
confusion_matrix(y_test,predXGB)
# Out:
# array([[ 9,  0],
#        [ 0, 22]])

# %%
test_set = pd.DataFrame(X_test,columns=['SST', 'SSC', 'AT', 'RH', 'SLP', 'TC'])
prediction = pd.DataFrame(predXGB,columns=['label'])
prediction['label'] = prediction['label'].map({0:'NPFZ',1:'PFZ'})
output = pd.concat([test_set,prediction],axis=1)
output.to_csv("output.csv",sep='\t', encoding='utf-8')

# %% [markdown]
# # Decision Tree

# %%
from sklearn import tree

# %%
clfD = tree.DecisionTreeClassifier()

# %%
clfD.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %%
result2 = clfD.predict(X_test)

# %%
accuracy_score(y_test,result2)
# Out:
# 0.967741935483871

# %%
confusion_matrix(y_test,result2)
# Out:
# array([[ 8,  1],
#        [ 0, 22]])

# %% [markdown]
# # Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()
gnb = gnb.fit(X_train, y_train)
pred = gnb.predict(X_test)
print(accuracy_score(pred,y_test))
# Out:
# 0.935483870968

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[ 9,  0],
#        [ 2, 20]])

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clfRF = RandomForestClassifier(random_state=0)
clfRF.fit(X_train, y_train)
predRF = clfRF.predict(X_test)

# %%
print(accuracy_score(predRF,y_test))
# Out:
# 1.0

# %%
confusion_matrix(y_test,predRF)
# Out:
# array([[ 9,  0],
#        [ 0, 22]])
